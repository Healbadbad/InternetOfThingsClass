# %% [markdown]
# # Ground Truth Data

# %% [markdown]
# Te

# %% [markdown]
# # The Data

# %% [markdown]
# The data is recorded at 50Hz and is formatted as follows:
#
# unix timestamp,  ax,ay,az,  gx,gy,gz,  temperature,  mx,my,mz,

# %%
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
from iotdata import IOTData
devices = ["Ground_Truth_Treadmill1", "Ground_Truth_Treadmill2", "Ground_Truth_Treadmill3", "Ground_Truth_Treadmill5"]
device = IOTData(devices, 'Ground_Truth_data\\03_27_16\\')

def plotarray(data):  
    length = len(data)
    for k in range(length):
        plt.plot(range(len(data[k])), data[k])

# %%
for k in range(len(devices)):
    figsize(17, 6)
    figure(k)
    device.initdata(devices[k])
    length = device.getLength()
    data = device.getSelection(0, length)
    plotarray(data [1:4])

# %%
device.initdata(devices[1])
data = device.getSelection(120300, 170000)
# plotarray(data[1:4])
plt.plot(data[0], data[3])

# %%
device.initdata(devices[1])
data = device.getSelection(170000, 250000)
# plotarray(data[1:4])
plt.plot(data[0], data[3])

# %% [raw]
# device.initdata(devices[1])
# length = device.getLength()
# numWindows = (length-30000 )/256
# device.getSelection(30000, 100000)
# theMean = device.featureWindowMean()[3]
# device.getSelection(0,30000)
#
# means = []
# devs = []
# for k in range(numWindows/2):
#     temp = device.getNextWindow()
#     means.append(device.featureWindowMean()[3] - theMean)
#     devs.append(device.featureWindowStdev()[3])
#
# plt.plot(range(len(means)), means)
# plt.plot(range(len(means)), devs)

# %% [raw]
# device.initdata(devices[0])
# length = device.getLength()
# numWindows = (length-60000 )/256
# device.getSelection(60000, 100000)
# theMean = device.featureWindowMean()[3]
# device.getSelection(0,60000)
#
# means = []
# devs = []
# for k in range(numWindows/2):
#     temp = device.getNextWindow()
#     means.append(device.featureWindowMean()[3] - theMean)
#     devs.append(device.featureWindowStdev()[3])
#
# plt.plot(range(len(means)), means)
# plt.plot(range(len(means)), devs)

# %% [markdown]
# # Matlab Features
# Yay matlab or something

# %% [markdown]
# device.startMatlab()
# steps = device.getSteps(device.window[1])
# plt.plot(range(len(steps)), steps)

# %% [markdown]
# import matlab
# matlab.double([5, 5])

# %% [markdown]
# print(device.featureWindowMean())
# print(len(device.featureWindowMean()))
# print(len(device.window))
# print(device.window[16][0])

# %%
from scipy import signal
import scipy

# %%
device.getNextWindow()
# freq = scipy.fftpack.fft(device.window[3]).real
# print freq
# plt.plot(power[0], freq)
# freq = device.featureFrequencySpectrumMean()
# print freq
# Out:
# []

# %%
print scipy.fftpack.fft(device.window[3]).real
# Out:
# [ -2.45821687e+03 +0.00000000e+00j   7.91802349e-02 -1.19991720e-01j
#   -1.27567060e-01 -1.73169068e-02j   8.78211929e-02 +3.23373144e-03j
#    2.10769884e-01 -2.48170186e-01j  -7.58473716e-02 -6.68392320e-02j
#   -5.43086442e-02 +1.05036517e-01j   6.39274307e-02 +2.41342715e-02j
#   -2.92107832e-02 +1.14601639e-01j  -6.36643355e-02 -9.75884582e-02j
#   -5.25307834e-02 +4.12770143e-02j  -6.34646301e-02 -5.02905911e-03j
#   -5.90906667e-02 +8.43387104e-02j  -9.27242131e-02 +6.11703873e-03j
#   -1.21147038e-01 +4.80877808e-02j  -2.72790848e-02 +2.15895512e-01j
#   -1.68282366e-01 +2.45301138e-01j  -2.33756320e-01 +5.76250373e-02j
#    1.08501449e-01 +2.25640889e-01j  -1.25387259e-01 +2.41681043e-01j
#    1.90794812e-01 +1.46447823e-01j  -6.23932523e-02 +3.57929883e-02j
#    1.01318641e-01 +1.20795609e-01j  -6.98812212e-02 -5.78889521e-05j
#    5.23986406e-02 -2.13520803e-03j   2.21633650e-01 +9.44854802e-02j
#    4.09956571e-01 -1.73120443e-01j   6.75565098e-02 -8.91603137e-02j
#    7.91107629e-02 -6.32902466e-02j   1.58780858e-01 -1.44641153e-01j
#   -3.82954632e-02 -4.36214675e-02j  -4.37347000e-02 -8.51854050e-02j
#   -4.46639371e-02 -4.96544620e-02j   8.68055039e-02 -5.65064175e-02j
#    6.90308341e-02 +1.45626801e-01j  -7.09298240e-02 -8.85789715e-02j
#    1.57777210e-01 -1.05634121e-01j   9.15477178e-02 -6.06427824e-03j
#   -2.25508426e-03 +2.16061314e-01j   7.39311098e-03 -6.74612455e-02j
#   -4.65241094e-02 -4.17858774e-03j   8.31789061e-02 +1.81303066e-01j
#    8.42744047e-02 -1.24672946e-01j   1.13573088e-01 +1.50790288e-02j
#    1.03595523e-01 -1.05149458e-01j   8.56591388e-02 -4.68278709e-02j
#   -1.09616799e-01 +3.11058448e-02j  -6.13247882e-02 -1.35770785e-01j
#   -1.47922918e-01 -7.38671195e-02j   9.03699122e-02 -3.66490725e-02j
#    1.23548905e-02 -7.85306046e-02j   5.36651998e-03 +6.29851124e-03j
#   -6.97179287e-02 -1.22011856e-02j   7.76971627e-02 -7.77328799e-02j
#    1.30479887e-01 +8.89037971e-02j   1.16945868e-01 +7.36371035e-02j
#   -5.68260082e-02 +7.36321343e-02j   8.15042702e-02 -1.66780681e-01j
#   -1.33458562e-01 +3.33382982e-02j  -8.69436213e-02 +6.26455813e-02j
#    9.33050897e-02 -2.12355218e-02j  -9.28410389e-02 +3.41912693e-02j
#   -4.74291507e-02 -9.23772634e-03j   1.51434833e-02 -1.08861995e-01j
#   -1.08433735e-01 -1.56626506e-01j   1.24303431e-01 -3.85842980e-02j
#    1.07083686e-01 +7.85062833e-02j   8.46873386e-03 +1.00184313e-01j
#    8.81487239e-02 -1.01142652e-01j   5.74434577e-03 +4.36851434e-02j
#    3.26436587e-02 +5.00765103e-02j  -1.46929347e-01 -7.32890641e-02j
#    1.33442404e-01 +5.51895593e-02j  -4.74836785e-02 +1.47101296e-01j
#    1.79895378e-02 -1.01555022e-01j   2.56755103e-02 -2.78716595e-02j
#   -1.10846618e-01 +1.24682149e-02j   5.43274738e-02 +1.56973599e-01j
#   -1.02188420e-02 +8.20576276e-02j   1.42742325e-02 +3.85933803e-02j
#    2.26058839e-01 +2.21136271e-01j  -2.18747639e-01 -3.95562280e-01j
#    6.12446808e-02 -7.22779231e-02j   5.15739288e-03 -7.97708779e-02j
#    6.78435079e-03 +9.50371940e-02j  -9.09977149e-02 -3.34164651e-02j
#   -6.09718382e-02 -2.82261501e-02j  -5.51599833e-02 -2.36595401e-02j
#   -7.98125510e-03 -4.87029026e-02j   3.17718005e-02 +1.06434008e-01j
#   -1.86133693e-02 -1.53581466e-01j  -8.94491441e-03 -1.41395113e-01j
#   -2.18033379e-01 +1.38446003e-01j  -1.69893746e-02 +4.95894966e-02j
#    1.14171071e-01 -6.20908567e-02j   7.48981589e-02 -1.01288825e-02j
#   -2.76252195e-02 -1.46169089e-03j   1.85038182e-01 +9.75004414e-02j
#    5.70893978e-02 -6.46090457e-02j   1.67065435e-02 +1.26219416e-02j
#   -1.14409198e-02 +2.11518335e-02j   1.44238054e-01 +1.12773350e-03j
#   -7.61056385e-02 -5.44525150e-02j  -6.28875411e-02 -4.59452651e-03j
#   -1.78553755e-02 -4.66595228e-02j  -1.11901326e-02 +9.50662172e-02j
#   -5.52766509e-02 -2.54257669e-02j  -1.93425573e-02 -7.55289708e-02j
#    1.15451884e-01 +7.57364768e-02j   5.68390803e-02 -7.67174928e-02j
#   -2.01276317e-01 +5.36719960e-02j   7.60273825e-03 +1.73255256e-01j
#    4.19536748e-02 +1.54762359e-01j   5.44064033e-02 -1.11338005e-01j
#    9.42999977e-02 +2.30315247e-01j   7.45933892e-02 -6.52973580e-03j
#   -1.60434213e-01 +5.42682503e-02j   1.19168689e-02 +1.12569927e-01j
#    1.19575565e-01 +1.57686851e-01j  -1.95059012e-02 -1.64114047e-01j
#    6.89420289e-02 +9.61590644e-02j   6.31181880e-02 +1.16963172e-01j
#    2.26728721e-02 -4.37783496e-02j   6.27558885e-02 -2.46977585e-02j
#    1.62138737e-01 +1.13984947e-01j   3.79224714e-02 -8.46261322e-02j
#   -4.80737335e-02 -8.49347354e-02j   4.55913375e-02 +2.10856416e-02j
#   -1.20481928e-01 +0.00000000e+00j   4.55913375e-02 -2.10856416e-02j
#   -4.80737335e-02 +8.49347354e-02j   3.79224714e-02 +8.46261322e-02j
#    1.62138737e-01 -1.13984947e-01j   6.27558885e-02 +2.46977585e-02j
#    2.26728721e-02 +4.37783496e-02j   6.31181880e-02 -1.16963172e-01j
#    6.89420289e-02 -9.61590644e-02j  -1.95059012e-02 +1.64114047e-01j
#    1.19575565e-01 -1.57686851e-01j   1.19168689e-02 -1.12569927e-01j
#   -1.60434213e-01 -5.42682503e-02j   7.45933892e-02 +6.52973580e-03j
#    9.42999977e-02 -2.30315247e-01j   5.44064033e-02 +1.11338005e-01j
#    4.19536748e-02 -1.54762359e-01j   7.60273825e-03 -1.73255256e-01j
#   -2.01276317e-01 -5.36719960e-02j   5.68390803e-02 +7.67174928e-02j
#    1.15451884e-01 -7.57364768e-02j  -1.93425573e-02 +7.55289708e-02j
#   -5.52766509e-02 +2.54257669e-02j  -1.11901326e-02 -9.50662172e-02j
#   -1.78553755e-02 +4.66595228e-02j  -6.28875411e-02 +4.59452651e-03j
#   -7.61056385e-02 +5.44525150e-02j   1.44238054e-01 -1.12773350e-03j
#   -1.14409198e-02 -2.11518335e-02j   1.67065435e-02 -1.26219416e-02j
#    5.70893978e-02 +6.46090457e-02j   1.85038182e-01 -9.75004414e-02j
#   -2.76252195e-02 +1.46169089e-03j   7.48981589e-02 +1.01288825e-02j
#    1.14171071e-01 +6.20908567e-02j  -1.69893746e-02 -4.95894966e-02j
#   -2.18033379e-01 -1.38446003e-01j  -8.94491441e-03 +1.41395113e-01j
#   -1.86133693e-02 +1.53581466e-01j   3.17718005e-02 -1.06434008e-01j
#   -7.98125510e-03 +4.87029026e-02j  -5.51599833e-02 +2.36595401e-02j
#   -6.09718382e-02 +2.82261501e-02j  -9.09977149e-02 +3.34164651e-02j
#    6.78435079e-03 -9.50371940e-02j   5.15739288e-03 +7.97708779e-02j
#    6.12446808e-02 +7.22779231e-02j  -2.18747639e-01 +3.95562280e-01j
#    2.26058839e-01 -2.21136271e-01j   1.42742325e-02 -3.85933803e-02j
#   -1.02188420e-02 -8.20576276e-02j   5.43274738e-02 -1.56973599e-01j
#   -1.10846618e-01 -1.24682149e-02j   2.56755103e-02 +2.78716595e-02j
#    1.79895378e-02 +1.01555022e-01j  -4.74836785e-02 -1.47101296e-01j
#    1.33442404e-01 -5.51895593e-02j  -1.46929347e-01 +7.32890641e-02j
#    3.26436587e-02 -5.00765103e-02j   5.74434577e-03 -4.36851434e-02j
#    8.81487239e-02 +1.01142652e-01j   8.46873386e-03 -1.00184313e-01j
#    1.07083686e-01 -7.85062833e-02j   1.24303431e-01 +3.85842980e-02j
#   -1.08433735e-01 +1.56626506e-01j   1.51434833e-02 +1.08861995e-01j
#   -4.74291507e-02 +9.23772634e-03j  -9.28410389e-02 -3.41912693e-02j
#    9.33050897e-02 +2.12355218e-02j  -8.69436213e-02 -6.26455813e-02j
#   -1.33458562e-01 -3.33382982e-02j   8.15042702e-02 +1.66780681e-01j
#   -5.68260082e-02 -7.36321343e-02j   1.16945868e-01 -7.36371035e-02j
#    1.30479887e-01 -8.89037971e-02j   7.76971627e-02 +7.77328799e-02j
#   -6.97179287e-02 +1.22011856e-02j   5.36651998e-03 -6.29851124e-03j
#    1.23548905e-02 +7.85306046e-02j   9.03699122e-02 +3.66490725e-02j
#   -1.47922918e-01 +7.38671195e-02j  -6.13247882e-02 +1.35770785e-01j
#   -1.09616799e-01 -3.11058448e-02j   8.56591388e-02 +4.68278709e-02j
#    1.03595523e-01 +1.05149458e-01j   1.13573088e-01 -1.50790288e-02j
#    8.42744047e-02 +1.24672946e-01j   8.31789061e-02 -1.81303066e-01j
#   -4.65241094e-02 +4.17858774e-03j   7.39311098e-03 +6.74612455e-02j
#   -2.25508426e-03 -2.16061314e-01j   9.15477178e-02 +6.06427824e-03j
#    1.57777210e-01 +1.05634121e-01j  -7.09298240e-02 +8.85789715e-02j
#    6.90308341e-02 -1.45626801e-01j   8.68055039e-02 +5.65064175e-02j
#   -4.46639371e-02 +4.96544620e-02j  -4.37347000e-02 +8.51854050e-02j
#   -3.82954632e-02 +4.36214675e-02j   1.58780858e-01 +1.44641153e-01j
#    7.91107629e-02 +6.32902466e-02j   6.75565098e-02 +8.91603137e-02j
#    4.09956571e-01 +1.73120443e-01j   2.21633650e-01 -9.44854802e-02j
#    5.23986406e-02 +2.13520803e-03j  -6.98812212e-02 +5.78889521e-05j
#    1.01318641e-01 -1.20795609e-01j  -6.23932523e-02 -3.57929883e-02j
#    1.90794812e-01 -1.46447823e-01j  -1.25387259e-01 -2.41681043e-01j
#    1.08501449e-01 -2.25640889e-01j  -2.33756320e-01 -5.76250373e-02j
#   -1.68282366e-01 -2.45301138e-01j  -2.72790848e-02 -2.15895512e-01j
#   -1.21147038e-01 -4.80877808e-02j  -9.27242131e-02 -6.11703873e-03j
#   -5.90906667e-02 -8.43387104e-02j  -6.34646301e-02 +5.02905911e-03j
#   -5.25307834e-02 -4.12770143e-02j  -6.36643355e-02 +9.75884582e-02j
#   -2.92107832e-02 -1.14601639e-01j   6.39274307e-02 -2.41342715e-02j
#   -5.43086442e-02 -1.05036517e-01j  -7.58473716e-02 +6.68392320e-02j
#    2.10769884e-01 +2.48170186e-01j   8.78211929e-02 -3.23373144e-03j
#   -1.27567060e-01 +1.73169068e-02j   7.91802349e-02 +1.19991720e-01j]

# %%
print len(device.window)
# Out:
# 17

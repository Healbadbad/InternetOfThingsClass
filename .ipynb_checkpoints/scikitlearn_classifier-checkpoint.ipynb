# %%
import pandas as pd
import numpy as np
import pickle as pkl
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("./Ground_Truth_compiled2.csv")
# randomly rearange the rows of the dataset
df = df.reindex(np.random.permutation(df.index))
data = df.as_matrix()
classifications = data[:,81]
data = data[:,0:81]
df.head()
# Out:
#       0.000132599235055  0.000185662184664  0.000136091051443  756769.394532  \
# 1851           0.001471           0.001346           0.009837   6.880211e+05
# 3353           0.027638           0.017888           0.039859   3.264659e+07
# 2941           0.459361           0.771986           1.866272   2.011806e+08
# 6787           0.001724           0.024503           0.005567   2.592260e+07
# 7040           0.002407           0.025077           0.004959   2.967904e+07
#
#       635465.476163  626549.680061  1.02768656959e-05  4.97094355163e-06  \
# 1851   1.364466e+06   6.486899e+05           0.000011           0.000004
# 3353   4.608441e+07   1.100858e+06           0.000018           0.000004
# 2941   6.935058e+08   1.351445e+07           0.000021           0.000054
# 6787   1.698449e+06   8.806486e+05           0.000022           0.000016
# 7040   4.859121e+06   9.347556e+05           0.000028           0.000019
#
#       1.85791092547e-05  0.000136684561142     ...       0.00855865668836  \
# 1851           0.000015           0.003064     ...               0.026062
# 3353           0.000019           0.069934     ...               0.112487
# 2941           0.000047           0.749595     ...               0.436331
# 6787           0.000025           0.003154     ...               0.028152
# 7040           0.000013           0.004090     ...               0.036339
#
#       0.010002242341  0.00820953665135  593.715048313  525.715512932  \
# 1851        0.025950          0.077131     632.077119     821.169846
# 3353        0.086271          0.141708    3673.893062    4727.306873
# 2941        0.615455          1.044975    8498.632981   19454.006377
# 6787        0.115148          0.054927    3794.404076     930.239381
# 7040        0.103726          0.049076    3711.852519    1704.146590
#
#       540.161922338  0.00206879829723  0.00148771423963  0.00293951662714  \
# 1851     552.182808          0.002288          0.001419          0.002870
# 3353     747.355261          0.002884          0.001482          0.002960
# 2941    2436.516697          0.003279          0.005419          0.005300
# 6787     708.058646          0.003318          0.002825          0.003585
# 7040     683.278499          0.003544          0.003254          0.002823
#
#       not_walking
# 1851  not_walking
# 3353  not_walking
# 2941      walking
# 6787  not_walking
# 7040  not_walking
#
# [5 rows x 82 columns]

# %%
# random forest classifier
rf = RandomForestClassifier(n_estimators = 100)
accuracy = cross_val_score(rf,data,classifications,cv=3)

# %%
print np.mean(accuracy)
# Out:
# 0.978082239156

# %%
# pickle the classifier
output = open('randomforestclassifier.pkl', 'wb')
pkl.dump(rf,output)
output.close()

# %%
featureInds = [1,2,3,11,12,13]
colInds = []
for i in range(int(81/16)):
    colInds.append([x+16*i for x in featureInds])
print colInds
# Out:
# [[1, 2, 3, 11, 12, 13], [17, 18, 19, 27, 28, 29], [33, 34, 35, 43, 44, 45], [49, 50, 51, 59, 60, 61], [65, 66, 67, 75, 76, 77]]

# %%
rf.fit(data,classifications)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
for k in range(200):
    print(rf.predict([data[k]]))
# Out:
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
# ['not_walking']
